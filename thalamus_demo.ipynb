# %%
from rake_nltk import Rake, Metric

thalamus = Rake(min_length=1, max_length=3)

thalamus.extract_keywords_from_text("""
The University of Toronto department of Linguistics is organizing a Philosophy of Language and
Mind psycholinguistic seminar that may be of interest to you. We recommend that you have
attended classes pertaining to the philosophy of mind and/or advanced psycholinguistic prior to
attending, for the discussed topics will be quite advanced in nature. We hope to see many students
who are passionate about the innerworkings of language and the processes of communicating
minds and meaning.
""")

keywords = thalamus.get_ranked_phrases()

for word in keywords[:20]:
    print(word)
# Out:
# see many students
# attended classes pertaining
# advanced psycholinguistic prior
# mind psycholinguistic seminar
# quite advanced
# toronto department
# discussed topics
# communicating minds
# mind
# university
# recommend
# processes
# philosophy
# passionate
# organizing
# nature
# meaning
# may
# linguistics
# language

# %%
thalamus.extract_keywords_from_text("""
PSA Career Day Event: March 26th


Calling all psychology students and enthusiasts! Are you unsure about what to do after you graduate? 
Do you want to explore career options available to you beyond academia? The Psychology Students’ Association (PSA) will be hosting the annual Career Day event 
on Friday, March 26th from 4-6pm EST to help you explore a variety of career paths with a psychology degree! There will be a panel of alumni who completed their 
undergraduate degrees in psychology at UofT and took non-traditional paths. They will be sharing their experiences as former psychology undergraduates at UofT and the trajectory of their career.

Our panelists’ fields and positions include:

Data Science  |  I/O psychology  |  Artificial Intelligence  |  Law  |  Consulting  |  Occupational therapy  |  Marketing 

You will:

Learn how to leverage a psychology degree and market your skills
Get assistance and encouragement in the process of career exploration
Network with people who have a psychology background and share resources and opportunities
 
This event is FREE and open to all UofT students! Please register here: https://forms.gle/ZsHUhpjgXvaiyqkD7 You can also submit questions that you have for the panel in the registration form. 
Any questions about the event? Please contact us at psa.copres@gmail.com. We look forward to seeing you!
""")

keywords = thalamus.get_ranked_phrases()

for word in keywords[:20]:
    print(word)
# Out:
# skills get assistance
# panelists ’ fields
# https :// forms
# please contact us
# march 26th calling
# former psychology undergraduates
# career exploration network
# also submit questions
# march 26th
# please register
# undergraduate degrees
# traditional paths
# took non
# share resources
# registration form
# psychology students
# psychology degree
# psychology background
# positions include
# occupational therapy

# %%
thalamus.extract_keywords_from_text("""
BioHacks 2021!

The University of Toronto’s Bioinformatics and Computational Biology Student’s Union presents BioHacks 2021
We’re looking for innovative students to participate and compete in our upcoming hackathon to create new projects or run analyses on anything related to the COVID-19 pandemic.

Date: March 13-14th, 2021
BioHacks 2021 is a virtual bioinformatics hackathon aiming to tackle epidemic health issues raised by COVID-19 through two interconnected streams:

Stream 1: Computational Methods against Diseases
Stream 2: Healthcare Tool Development

MORE INFO!

""")

keywords = thalamus.get_ranked_phrases()

for word in keywords[:20]:
    print(word)
# Out:
# two interconnected streams
# healthcare tool development
# create new projects
# diseases stream 2
# 2021 biohacks 2021
# biohacks 2021
# stream 1
# upcoming hackathon
# run analyses
# march 13
# innovative students
# computational methods
# anything related
# toronto ’
# 19 pandemic
# ’
# 19
# university
# participate
# looking

# %%
thalamus.extract_keywords_from_text("""
Fundamentals of Synthetic Biology Course- SYNB1. 

CSBERG (Canadian Synthetic Biology Education Research Group) is currently recruiting students to take part in the second iteration of our Fundamentals of Synthetic Biology Course- SYNB1. 

If you are interested in the engineering aspect of biology, then this is the course for you! Spots are reserved for wet lab students and 
dry lab computational/mathematics students. The course will run virtually every weekend in March 2021; 12-2pm EST.

A certificate will be presented upon completion of the course.

See the syllabus here.

See the sign-up sheet here.

Apply now!

Limited spots are available.

 

Deadline is February 22nd 2021 .
""")

keywords = thalamus.get_ranked_phrases()

for word in keywords[:20]:
    print(word)
# Out:
# presented upon completion
# dry lab computational
# wet lab students
# currently recruiting students
# february 22nd 2021
# synthetic biology course
# mathematics students
# march 2021
# take part
# second iteration
# engineering aspect
# 2pm est
# limited spots
# course
# biology
# spots
# synb1
# syllabus
# sign
# sheet

# %%
thalamus.extract_keywords_from_text("""
CVR-VISTA Vision Science Summer School (CVRSS), 2021

YORK UNIVERSITY, TORONTO, CANADA

The Centre for Vision Research https://cvr.yorku.ca/ at York University https://www.yorku.ca/ in Toronto, Canada offers a one-week undergraduate summer 
school on vision science in cooperation with the Vision: Science to Applications (VISTA) vista.info.yorku.ca  initiative.
In the past, the CVRSS has been an expenses-paid, in-person event but due to the COVID-19 pandemic the 2021 
version will be wholly virtual (while maintaining the intimate and interactive nature of the experience). 
This year's program will be held July 5th - 9th, 2021.

The program includes talks by CVR faculty members on current research topics in vision science, as well as (virtual) hands-on experience 
in CVR laboratories. The curriculum reflects the wide range of research areas at CVR, which includes research on human visual perception, 
computer vision, machine learning, visual neuroscience, digital media, immersive environments, and visual disorders.
The program accepts undergraduate students who are interested in pursuing a career in scientific research. 
It is intended mainly for students who are planning to apply to graduate school in the fall of 2021/2022 (for entry in fall 2022/2023), 
and who are interested in investigating vision science as an area of research. Citizens of all countries are eligible. 
The application deadline is March 26th, 2021.

Application instructions are available on the CVR summer school website (https://www.yorku.ca/cvr/summer-school/ ).  
We are accepting applications from now until March 26th, 2021. Applicants will be notified of decisions by mid-April. 
We expect to accept between 30 and 40 students. 
For further information please see the attached flyer, the website https://www.yorku.ca/cvr/summer-school/ or write to cvrss@yorku.ca

 
""")

keywords = thalamus.get_ranked_phrases()

for word in keywords[:20]:
    print(word)
# Out:
# information please see
# https :// www
# held july 5th
# human visual perception
# cvr faculty members
# current research topics
# program includes talks
# investigating vision science
# includes research
# visual neuroscience
# visual disorders
# wide range
# vision science
# scientific research
# research areas
# person event
# march 26th
# machine learning
# interactive nature
# intended mainly

# %%
thalamus.extract_keywords_from_text("""
COG415H1: Cognitive Science in Practice
Hours: 
18L/15P
This course provides COG students with the opportunities to practice quantitative and qualitative evaluation and assessment methods 
in real world situations and juxtapose theory with practice. Placement activities will ground topics such as problem solving, logistics, 
decision making, etc., through practical application, individual and group / in-class critical reflection.

Prerequisite: 
COG250Y1, COG341H1/​COG342H1, PSY370H1

Distribution Requirements: 
Science
Breadth Requirements: 
Thought, Belief and Behaviour (2)
Program Area Section: 
University College
""")

keywords = thalamus.get_ranked_phrases()

for word in keywords[:20]:
    print(word)
# Out:
# real world situations
# psy370h1 distribution requirements
# program area section
# cog341h1 /​ cog342h1
# class critical reflection
# science breadth requirements
# cognitive science
# university college
# qualitative evaluation
# problem solving
# practical application
# placement activities
# juxtapose theory
# ground topics
# etc .,
# decision making
# assessment methods
# practice quantitative
# practice hours
# practice

# %%
thalamus.extract_keywords_from_text("""
COG250Y1: Introduction to Cognitive Science 
Hours: 
78L
An introduction to the problems, theories and research [strategies central to the interdisciplinary field 
focusing on the nature and organization of the human mind and other cognitive systems. 
Interrelations among the philosophical, psychological, linguistic 
and computer science aspects of the field are emphasized.
""")

keywords = thalamus.get_ranked_phrases()

for word in keywords[:20]:
    print(word)
# Out:
# computer science aspects
# cognitive science hours
# interdisciplinary field focusing
# cognitive systems
# strategies central
# interrelations among
# human mind
# field
# theories
# research
# psychological
# problems
# philosophical
# organization
# nature
# linguistic
# introduction
# emphasized
# cog250y1
# 78l

# %%
thalamus.extract_keywords_from_text("""
CSC384H1: Introduction to Artificial Intelligence
Hours: 
24L/12T
Theories and algorithms that capture (or approximate) some of the core elements of computational intelligence. 
Topics include: search; logical representations 
and reasoning, classical automated planning, representing and reasoning with uncertainty, 
learning, decision making (planning) under uncertainty. 
Assignments provide practical experience, in both theory and programming, of the core topics.
""")

keywords = thalamus.get_ranked_phrases()

for word in keywords[:20]:
    print(word)
# Out:
# artificial intelligence hours
# classical automated planning
# computational intelligence
# topics include
# logical representations
# decision making
# core topics
# core elements
# 12t theories
# planning
# uncertainty
# theory
# search
# representing
# reasoning
# programming
# learning
# introduction
# csc384h1
# capture
